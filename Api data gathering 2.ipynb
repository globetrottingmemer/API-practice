# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/trending/all/day?api_key=2564dac439ddc809aca9f4cd9a2b76e6')

# %%
#convert data into json format
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/wcKFYIiVDvRURrzglV9kGu7fpfY.jpg',
#   'genre_ids': [14, 28, 12],
#   'id': 453395,
#   'media_type': 'movie',
#   'title': 'Doctor Strange in the Multiverse of Madness',
#   'original_language': 'en',
#   'original_title': 'Doctor Strange in the Multiverse of Madness',
#   'overview': 'Doctor Strange, with the help of mystical allies both old and new, traverses the mind-bending and dangerous alternate realities of the Multiverse to confront a mysterious new adversary.',
#   'popularity': 16751.01,
#   'poster_path': '/9Gtg2DzBhmYamXBS1hKAhiwbBKS.jpg',
#   'release_date': '2022-05-04',
#   'video': False,
#   'vote_average': 7.543,
#   'vote_count': 3551},
#  {'adult': False,
#   'backdrop_path': '/yGNnjoIGOdQy3douq60tULY8teK.jpg',
#   'genre_ids': [10765, 37],
#   'id': 63247,
#   'media_type': 'tv',
#   'name': 'Westworld',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_name': 'Westworld',
# ...

# %%
#converting this list into df

df=pd.DataFrame(response.json()['results'])
df.head(2)
# Out:
#    adult                     backdrop_path     genre_ids      id media_type  \
# 0  False  /wcKFYIiVDvRURrzglV9kGu7fpfY.jpg  [14, 28, 12]  453395      movie
# 1  False  /yGNnjoIGOdQy3douq60tULY8teK.jpg   [10765, 37]   63247         tv
#
#                                          title original_language  \
# 0  Doctor Strange in the Multiverse of Madness                en
# 1                                          NaN                en
#
#                                 original_title  \
# 0  Doctor Strange in the Multiverse of Madness
# 1                                          NaN
#
#                                             overview  popularity  \
# 0  Doctor Strange, with the help of mystical alli...   16751.010
# 1  A dark odyssey about the dawn of artificial co...     248.548
#
#                         poster_path release_date  video  vote_average  \
# 0  /9Gtg2DzBhmYamXBS1hKAhiwbBKS.jpg   2022-05-04  False         7.543
# ...

# %%
df.shape
# Out:
# (20, 19)
